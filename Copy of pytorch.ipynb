# %%
# Linear Regression without optim and dataloader


import torch, torchvision
import numpy as np
inputs=torch.tensor([[73.0,67,43],
       [91,88,64],
       [87,134,58],
       [102,43,37],
       [69,96,70]])
targets=torch.tensor([[56.0,70],
                      [81,101],
                      [119,133],
                      [22,37],
                      [103,119]])
# print(inputs)
# print(targets)
weights=torch.randn(2,3,requires_grad=True)
bias=torch.randn(2,requires_grad=True)
# print("weights= ",weights)
# print("weights transpose= ",weights.T)
def rms(pred):
  diff=pred-targets
  return torch.sqrt(torch.sum(diff*diff)/pred.numel())


for epoch in range(2000):
    pred=inputs@(weights.T)+bias
    error=rms(pred)
    error.backward()
    with torch.no_grad():
        weights-=weights.grad*0.0001
        bias-=bias.grad*0.0001
        weights.grad.zero_()
        bias.grad.zero_()
pred=inputs@weights.T+bias
print("targets= ",targets)
print("predictions= ",pred)
print("rms= ",rms(pred))
# Out:
# targets=  tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])
# predictions=  tensor([[ 66.2267,  72.9874],
#         [ 61.2039, 108.5132],
#         [151.8900, 110.8151],
#         [ 71.7962,  53.1780],
#         [ 35.6286, 123.3527]], grad_fn=<AddBackward0>)
# rms=  tensor(30.7165, grad_fn=<SqrtBackward>)

# %%
import torch
import numpy as np
import torch.nn as nn

# %%
#Linear regression with optim and dataloader

inputs=torch.tensor([[73.0,67,43],
                     [91,88,64],
                     [87,134,58],
                     [102,43,37],
                     [69,96,70],
                     [73.0,67,43],
                     [91,88,64],
                     [87,134,58],
                     [102,43,37],
                     [69,96,70],
                     [73.0,67,43],
                     [91,88,64],
                     [87,134,58],
                     [102,43,37],
                     [69,96,70]])

targets=torch.tensor([[56.0,70],
                      [81,101],
                      [119,133],
                      [22,37],
                      [103,119],
                      [56.0,70],
                      [81,101],
                      [119,133],
                      [22,37],
                      [103,119],
                      [56.0,70],
                      [81,101],
                      [119,133],
                      [22,37],
                      [103,119]])

from torch.utils.data import TensorDataset
from torch.utils.data import DataLoader
import torch.nn.functional as F

train_tds=TensorDataset(inputs,targets)
# print(train_tds[:3])

train_dl=DataLoader(train_tds,5,shuffle=True)
# for xt,yt in train_dl:
#     print(xt)
#     print(yt)

model=nn.Linear(3,2)
print(model.weight)
loss_fn=F.mse_loss
opt=torch.optim.SGD(model.parameters(),1e-5)
# loss=loss_fn(model(inputs),targets)
# print(loss)
for epochs in range(100):
    for xb,yb in train_dl:
        pred=model(xb)
        loss=loss_fn(pred,yb)
        loss.backward()
        opt.step()
        opt.zero_grad()
    print("loss in ",epochs,"epoch is ",loss_fn(model(inputs),targets))
print(loss_fn(model(inputs),targets))
# Out:
# Parameter containing:
# tensor([[-0.2777,  0.2508,  0.5306],
#         [ 0.5135, -0.3960,  0.4840]], requires_grad=True)
# loss in  0 epoch is  tensor(1654.0880, grad_fn=<MseLossBackward>)
# loss in  1 epoch is  tensor(967.4633, grad_fn=<MseLossBackward>)
# loss in  2 epoch is  tensor(721.8712, grad_fn=<MseLossBackward>)
# loss in  3 epoch is  tensor(640.3220, grad_fn=<MseLossBackward>)
# loss in  4 epoch is  tensor(603.5305, grad_fn=<MseLossBackward>)
# loss in  5 epoch is  tensor(576.3156, grad_fn=<MseLossBackward>)
# loss in  6 epoch is  tensor(553.1783, grad_fn=<MseLossBackward>)
# loss in  7 epoch is  tensor(531.7557, grad_fn=<MseLossBackward>)
# loss in  8 epoch is  tensor(511.4896, grad_fn=<MseLossBackward>)
# loss in  9 epoch is  tensor(492.3198, grad_fn=<MseLossBackward>)
# loss in  10 epoch is  tensor(473.7532, grad_fn=<MseLossBackward>)
# loss in  11 epoch is  tensor(455.5462, grad_fn=<MseLossBackward>)
# loss in  12 epoch is  tensor(437.9612, grad_fn=<MseLossBackward>)
# loss in  13 epoch is  tensor(420.9673, grad_fn=<MseLossBackward>)
# loss in  14 epoch is  tensor(405.1302, grad_fn=<MseLossBackward>)
# loss in  15 epoch is  tensor(389.8620, grad_fn=<MseLossBackward>)
# loss in  16 epoch is  tensor(375.1986, grad_fn=<MseLossBackward>)
# loss in  17 epoch is  tensor(361.1452, grad_fn=<MseLossBackward>)
# loss in  18 epoch is  tensor(347.1959, grad_fn=<MseLossBackward>)
# loss in  19 epoch is  tensor(334.0956, grad_fn=<MseLossBackward>)
# loss in  20 epoch is  tensor(321.5631, grad_fn=<MseLossBackward>)
# loss in  21 epoch is  tensor(309.4338, grad_fn=<MseLossBackward>)
# loss in  22 epoch is  tensor(297.7287, grad_fn=<MseLossBackward>)
# loss in  23 epoch is  tensor(286.5859, grad_fn=<MseLossBackward>)
# loss in  24 epoch is  tensor(275.9417, grad_fn=<MseLossBackward>)
# loss in  25 epoch is  tensor(265.6088, grad_fn=<MseLossBackward>)
# loss in  26 epoch is  tensor(255.5925, grad_fn=<MseLossBackward>)
# loss in  27 epoch is  tensor(245.9753, grad_fn=<MseLossBackward>)
# loss in  28 epoch is  tensor(236.7240, grad_fn=<MseLossBackward>)
# loss in  29 epoch is  tensor(228.0224, grad_fn=<MseLossBackward>)
# loss in  30 epoch is  tensor(219.5267, grad_fn=<MseLossBackward>)
# loss in  31 epoch is  tensor(211.5276, grad_fn=<MseLossBackward>)
# loss in  32 epoch is  tensor(203.0304, grad_fn=<MseLossBackward>)
# loss in  33 epoch is  tensor(195.4438, grad_fn=<MseLossBackward>)
# loss in  34 epoch is  tensor(188.1195, grad_fn=<MseLossBackward>)
# loss in  35 epoch is  tensor(181.1104, grad_fn=<MseLossBackward>)
# loss in  36 epoch is  tensor(174.4050, grad_fn=<MseLossBackward>)
# loss in  37 epoch is  tensor(167.8330, grad_fn=<MseLossBackward>)
# loss in  38 epoch is  tensor(161.6703, grad_fn=<MseLossBackward>)
# loss in  39 epoch is  tensor(155.2800, grad_fn=<MseLossBackward>)
# loss in  40 epoch is  tensor(149.5265, grad_fn=<MseLossBackward>)
# loss in  41 epoch is  tensor(143.9220, grad_fn=<MseLossBackward>)
# loss in  42 epoch is  tensor(138.6143, grad_fn=<MseLossBackward>)
# loss in  43 epoch is  tensor(133.4586, grad_fn=<MseLossBackward>)
# loss in  44 epoch is  tensor(128.3297, grad_fn=<MseLossBackward>)
# loss in  45 epoch is  tensor(123.5486, grad_fn=<MseLossBackward>)
# loss in  46 epoch is  tensor(118.9772, grad_fn=<MseLossBackward>)
# loss in  47 epoch is  tensor(114.5193, grad_fn=<MseLossBackward>)
# loss in  48 epoch is  tensor(110.1694, grad_fn=<MseLossBackward>)
# loss in  49 epoch is  tensor(106.0640, grad_fn=<MseLossBackward>)
# loss in  50 epoch is  tensor(102.1719, grad_fn=<MseLossBackward>)
# loss in  51 epoch is  tensor(98.2754, grad_fn=<MseLossBackward>)
# loss in  52 epoch is  tensor(94.5988, grad_fn=<MseLossBackward>)
# loss in  53 epoch is  tensor(91.0518, grad_fn=<MseLossBackward>)
# loss in  54 epoch is  tensor(87.6701, grad_fn=<MseLossBackward>)
# loss in  55 epoch is  tensor(84.4274, grad_fn=<MseLossBackward>)
# loss in  56 epoch is  tensor(81.3033, grad_fn=<MseLossBackward>)
# loss in  57 epoch is  tensor(78.2527, grad_fn=<MseLossBackward>)
# loss in  58 epoch is  tensor(75.3476, grad_fn=<MseLossBackward>)
# loss in  59 epoch is  tensor(72.5612, grad_fn=<MseLossBackward>)
# loss in  60 epoch is  tensor(69.8053, grad_fn=<MseLossBackward>)
# loss in  61 epoch is  tensor(67.2583, grad_fn=<MseLossBackward>)
# loss in  62 epoch is  tensor(64.7940, grad_fn=<MseLossBackward>)
# loss in  63 epoch is  tensor(62.3745, grad_fn=<MseLossBackward>)
# loss in  64 epoch is  tensor(60.0258, grad_fn=<MseLossBackward>)
# loss in  65 epoch is  tensor(57.8206, grad_fn=<MseLossBackward>)
# loss in  66 epoch is  tensor(55.6719, grad_fn=<MseLossBackward>)
# loss in  67 epoch is  tensor(53.5478, grad_fn=<MseLossBackward>)
# loss in  68 epoch is  tensor(51.5547, grad_fn=<MseLossBackward>)
# loss in  69 epoch is  tensor(49.6634, grad_fn=<MseLossBackward>)
# loss in  70 epoch is  tensor(47.8770, grad_fn=<MseLossBackward>)
# loss in  71 epoch is  tensor(46.0436, grad_fn=<MseLossBackward>)
# loss in  72 epoch is  tensor(44.3616, grad_fn=<MseLossBackward>)
# loss in  73 epoch is  tensor(42.7234, grad_fn=<MseLossBackward>)
# loss in  74 epoch is  tensor(41.1666, grad_fn=<MseLossBackward>)
# loss in  75 epoch is  tensor(39.6744, grad_fn=<MseLossBackward>)
# loss in  76 epoch is  tensor(38.2238, grad_fn=<MseLossBackward>)
# loss in  77 epoch is  tensor(36.7840, grad_fn=<MseLossBackward>)
# loss in  78 epoch is  tensor(35.4480, grad_fn=<MseLossBackward>)
# loss in  79 epoch is  tensor(34.0984, grad_fn=<MseLossBackward>)
# loss in  80 epoch is  tensor(32.8454, grad_fn=<MseLossBackward>)
# loss in  81 epoch is  tensor(31.6363, grad_fn=<MseLossBackward>)
# loss in  82 epoch is  tensor(30.4802, grad_fn=<MseLossBackward>)
# loss in  83 epoch is  tensor(29.3810, grad_fn=<MseLossBackward>)
# loss in  84 epoch is  tensor(28.3139, grad_fn=<MseLossBackward>)
# loss in  85 epoch is  tensor(27.2920, grad_fn=<MseLossBackward>)
# loss in  86 epoch is  tensor(26.3070, grad_fn=<MseLossBackward>)
# loss in  87 epoch is  tensor(25.3452, grad_fn=<MseLossBackward>)
# loss in  88 epoch is  tensor(24.4055, grad_fn=<MseLossBackward>)
# loss in  89 epoch is  tensor(23.5306, grad_fn=<MseLossBackward>)
# loss in  90 epoch is  tensor(22.6663, grad_fn=<MseLossBackward>)
# loss in  91 epoch is  tensor(21.8511, grad_fn=<MseLossBackward>)
# loss in  92 epoch is  tensor(21.0766, grad_fn=<MseLossBackward>)
# loss in  93 epoch is  tensor(20.3092, grad_fn=<MseLossBackward>)
# loss in  94 epoch is  tensor(19.6136, grad_fn=<MseLossBackward>)
# loss in  95 epoch is  tensor(18.8972, grad_fn=<MseLossBackward>)
# loss in  96 epoch is  tensor(18.2249, grad_fn=<MseLossBackward>)
# loss in  97 epoch is  tensor(17.5243, grad_fn=<MseLossBackward>)
# loss in  98 epoch is  tensor(16.9094, grad_fn=<MseLossBackward>)
# loss in  99 epoch is  tensor(16.3106, grad_fn=<MseLossBackward>)
# tensor(16.3106, grad_fn=<MseLossBackward>)

# %%
pred=model(inputs)
print(targets)
print(pred)
# Out:
# tensor([[ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.],
#         [ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.],
#         [ 56.,  70.],
#         [ 81., 101.],
#         [119., 133.],
#         [ 22.,  37.],
#         [103., 119.]])
# tensor([[ 57.8042,  71.8871],
#         [ 82.8208, 101.1777],
#         [116.2753, 128.9562],
#         [ 24.2515,  46.8886],
#         [101.2517, 114.1775],
#         [ 57.8042,  71.8871],
#         [ 82.8208, 101.1777],
#         [116.2753, 128.9562],
#         [ 24.2515,  46.8886],
#         [101.2517, 114.1775],
#         [ 57.8042,  71.8871],
#         [ 82.8208, 101.1777],
#         [116.2753, 128.9562],
#         [ 24.2515,  46.8886],
#         [101.2517, 114.1775]], grad_fn=<AddmmBackward>)

# %%
model(torch.tensor([[75,63,44.]]))
# Out:
# tensor([[54.6434, 69.6568]], grad_fn=<AddmmBackward>)
